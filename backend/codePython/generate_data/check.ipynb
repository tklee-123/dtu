# %%
from pymongo import MongoClient
from bson.objectid import ObjectId
import random
import datetime

# %%
client = MongoClient('mongodb+srv://root:Vly.19952003@cluster0.jmil5cr.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
# client = MongoClient('mongodb://localhost:27017')
db = client['dtu']  # Choose your database
answered_question_collection = db['answered_questions']  # Collection AnsweredQuestion
question_collection = db['questions']  
player_collection = db['players']

# %%
pipeline = [
    {"$unwind": "$questions"},  # Tách mảng questions thành các documents riêng lẻ
    {"$project": {"_id": "$questions._id"}}  # Chỉ lấy trường _id của mỗi câu hỏi
]

# Thực hiện truy vấn aggregation
result = answered_question_collection.aggregate(pipeline)

# Lặp qua kết quả và tạo danh sách các _id
question_ids = [doc["_id"] for doc in result]

print(len(set(question_ids)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 10
#       7 result = answered_question_collection.aggregate(pipeline)
#       9 # Lặp qua kết quả và tạo danh sách các _id
# ---> 10 question_ids = [doc["_id"] for doc in result]
#      12 print(len(set(question_ids)))
#
# Cell In[30], line 10, in <listcomp>(.0)
#       7 result = answered_question_collection.aggregate(pipeline)
#       9 # Lặp qua kết quả và tạo danh sách các _id
# ---> 10 question_ids = [doc["_id"] for doc in result]
#      12 print(len(set(question_ids)))
#
# File c:\Users\WIN\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\command_cursor.py:310, in CommandCursor.next(self)
#     308 # Block until a document is returnable.
#     309 while self.alive:
# --> 310     doc = self._try_next(True)
#     311     if doc is not None:
#     312         return doc
#
# ...

# %%
client = MongoClient('mongodb+srv://root:Vly.19952003@cluster0.jmil5cr.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
# client = MongoClient('mongodb://localhost:27017')
db = client['dtu']  # Choose your database
player_collection = db['players']  

# Get player IDs and write them to a text file
player_ids = player_collection.find({}, {"_id": 1})
ids = [player["_id"] for player in player_ids]
ids
# Out:
# [ObjectId('6626294d1253ec306d0aba97'),
#  ObjectId('6626294d1253ec306d0aba98'),
#  ObjectId('6626294d1253ec306d0aba99'),
#  ObjectId('6626294d1253ec306d0aba9a'),
#  ObjectId('6626294d1253ec306d0aba9b'),
#  ObjectId('6626294d1253ec306d0aba9c'),
#  ObjectId('6626294d1253ec306d0aba9d'),
#  ObjectId('6626294d1253ec306d0aba9e'),
#  ObjectId('6626294d1253ec306d0aba9f'),
#  ObjectId('6626294d1253ec306d0abaa0'),
#  ObjectId('6626294d1253ec306d0abaa1'),
#  ObjectId('6626294d1253ec306d0abaa2'),
#  ObjectId('6626294d1253ec306d0abaa3'),
#  ObjectId('6626294d1253ec306d0abaa4'),
#  ObjectId('6626294d1253ec306d0abaa5'),
#  ObjectId('6626294d1253ec306d0abaa6'),
#  ObjectId('6626294d1253ec306d0abaa7'),
#  ObjectId('6626294d1253ec306d0abaa8'),
#  ObjectId('6626294d1253ec306d0abaa9'),
#  ObjectId('6626294d1253ec306d0abaaa'),
#  ObjectId('6626294d1253ec306d0abaab'),
#  ObjectId('6626294d1253ec306d0abaac'),
#  ObjectId('6626294d1253ec306d0abaad'),
#  ObjectId('6626294d1253ec306d0abaae'),
# ...

# %%
import time

start_time = time.time()

player_info = player_collection.find({"_id": {"$in": ids}})
for info in player_info:
    print(info['major'])  

end_time = time.time()
query_time = end_time - start_time
print("Query executed in", query_time, "seconds")
# Out:
# [6, 7, 8, 4]
# [7, 8, 6, 2]
# [5, 4, 3, 6]
# [3, 8, 1, 6]
# [5, 6, 8, 2]
# [2, 7, 6, 1]
# [5, 4, 2, 1]
# [4, 8, 5, 1]
# [1, 6, 2, 3]
# [3, 1, 2, 5]
# [6, 4, 7, 8]
# [2, 7, 8, 5]
# [3, 5, 7, 6]
# [3, 2, 6, 8]
# [4, 6, 1, 8]
# [3, 8, 1, 2]
# [1, 2, 3, 4]
# [8, 5, 4, 3]
# [8, 7, 1, 5]
# [7, 4, 3, 1]
# [6, 3, 4, 2]
# [2, 4, 1, 5]
# [8, 3, 6, 1]
# [4, 3, 5, 1]
# [3, 4, 2, 5]
# [3, 8, 7, 2]
# [4, 2, 6, 3]
# [8, 3, 1, 5]
# [8, 6, 5, 1]
# [8, 3, 4, 1]
# [3, 4, 6, 2]
# [8, 4, 1, 6]
# [4, 2, 7, 8]
# [4, 7, 5, 2]
# [4, 6, 7, 8]
# [7, 5, 4, 8]
# [4, 1, 3, 6]
# [4, 6, 2, 7]
# [5, 2, 7, 8]
# [1, 2, 5, 4]
# [3, 5, 8, 4]
# [7, 5, 3, 8]
# [8, 6, 3, 1]
# [6, 3, 8, 2]
# [2, 6, 8, 3]
# [5, 1, 3, 6]
# [1, 7, 3, 4]
# [3, 8, 7, 4]
# [1, 3, 6, 5]
# [8, 3, 4, 2]
# [3, 7, 2, 6]
# [1, 5, 7, 3]
# [5, 8, 7, 6]
# [8, 5, 1, 3]
# [2, 6, 1, 4]
# [2, 6, 3, 7]
# [4, 1, 2, 5]
# [1, 7, 8, 2]
# [5, 2, 1, 8]
# [7, 1, 2, 4]
# [3, 7, 5, 6]
# [2, 4, 8, 3]
# [1, 8, 3, 7]
# [5, 2, 1, 7]
# [3, 7, 5, 6]
# [8, 2, 6, 3]
# ...

# %%
for id in ids:
    cursor = player_collection.find({"_id":id},{})
    for info in cursor:
        print(info['major'])
# Out:
# [6, 7, 8, 4]
# [7, 8, 6, 2]
# [5, 4, 3, 6]
# [3, 8, 1, 6]
# [5, 6, 8, 2]
# [2, 7, 6, 1]
# [5, 4, 2, 1]
# [4, 8, 5, 1]
# [1, 6, 2, 3]
# [3, 1, 2, 5]
# [6, 4, 7, 8]
# [2, 7, 8, 5]
# [3, 5, 7, 6]
# [3, 2, 6, 8]
# [4, 6, 1, 8]
# [3, 8, 1, 2]
# [1, 2, 3, 4]
# [8, 5, 4, 3]
# [8, 7, 1, 5]
# [7, 4, 3, 1]
# [6, 3, 4, 2]
# [2, 4, 1, 5]
# [8, 3, 6, 1]
# [4, 3, 5, 1]
# [3, 4, 2, 5]
# [3, 8, 7, 2]
# [4, 2, 6, 3]
# [8, 3, 1, 5]
# [8, 6, 5, 1]
# [8, 3, 4, 1]
# [3, 4, 6, 2]
# [8, 4, 1, 6]
# [4, 2, 7, 8]
# [4, 7, 5, 2]
# [4, 6, 7, 8]
# [7, 5, 4, 8]
# [4, 1, 3, 6]
# [4, 6, 2, 7]
# [5, 2, 7, 8]
# [1, 2, 5, 4]
# [3, 5, 8, 4]
# [7, 5, 3, 8]
# [8, 6, 3, 1]
# [6, 3, 8, 2]
# [2, 6, 8, 3]
# [5, 1, 3, 6]
# [1, 7, 3, 4]
# [3, 8, 7, 4]
# [1, 3, 6, 5]
# [8, 3, 4, 2]
# [3, 7, 2, 6]
# [1, 5, 7, 3]
# [5, 8, 7, 6]
# [8, 5, 1, 3]
# [2, 6, 1, 4]
# [2, 6, 3, 7]
# [4, 1, 2, 5]
# [1, 7, 8, 2]
# [5, 2, 1, 8]
# [7, 1, 2, 4]
# [3, 7, 5, 6]
# [2, 4, 8, 3]
# [1, 8, 3, 7]
# [5, 2, 1, 7]
# [3, 7, 5, 6]
# [8, 2, 6, 3]
# ...
